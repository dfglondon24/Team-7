# %%
import pandas as pd

# %%
map_and_pop_data = pd.read_excel("shared_data_read_only/Data/AfriKids/InternalData/Ghana Districts Map and Population 2020.xlsx")
internal_master_stats = pd.read_excel("shared_data_read_only/Data/AfriKids/InternalData/1. Master Stats 2023.xlsx")
key_stats_ghana = pd.read_excel("shared_data_read_only/Data/AfriKids/InternalData/2. Key stats Ghana and Northern Ghana 2021.xlsx")
key_stats_ghana_inc21= pd.read_excel("shared_data_read_only/Data/AfriKids/InternalData/2023 Key stats inc 21 census.xlsx")

# %%
df = internal_master_stats
#(df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)

# %% [markdown]
# ## 1. Master Stats 2023
# Cleaning dataset to retrieve education related information

# %%
# "General stats" EDA
df_general_stats = pd.read_excel('shared_data_read_only/Data/AfriKids/InternalData/1. Master Stats 2023.xlsx', sheet_name='General stats')

# Show the first few rows and basic info for an overview
df_general_stats_info = df_general_stats.info()
df_general_stats_head = df_general_stats.head()

df_general_stats_info, df_general_stats_head
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 14 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Use the + or - at the left of the row numbers to open/close the groups  190 non-null    object
#  1   Notes                                                                   77 non-null     object
#  2   Ghana                                                                   134 non-null    object
#  3   UER                                                                     131 non-null    object
#  4   Pre-2018 Northern Region                                                87 non-null     object
#  5   UWR                                                                     122 non-null    object
#  6   NR                                                                      38 non-null     float64
#  7   NER                                                                     38 non-null     float64
#  8   Sav.R                                                                   38 non-null     float64
#  9   Northern regions combined                                               96 non-null     object
#  10  Source                                                                  149 non-null    object
#  11  Page#                                                                   120 non-null    object
#  12  Date                                                                    145 non-null    object
#  13  Alternative ways to phrase/perspective                                  10 non-null     object
# dtypes: float64(3), object(11)
# memory usage: 21.1+ KB
# (None,
#    Use the + or - at the left of the row numbers to open/close the groups  \
#  0                                            General
#  1                                         Population
#  2                                        Population
#  3                    Percentage of female population
#  4                      Percentage of male population
#
#                      Notes     Ghana       UER Pre-2018 Northern Region  \
#  0  Demographics, AfriKids       NaN       NaN                      NaN
#  1                     NaN       NaN       NaN                      NaN
#  2                     NaN  30832019   1301226                      NaN
#  3                     NaN  0.506992  0.514871                      NaN
#  4                     NaN  0.493008  0.485129                      NaN
#
#          UWR            NR            NER          Sav.R  \
#  0       NaN           NaN            NaN            NaN
#  1       NaN           NaN            NaN            NaN
#  2    901502  2.310939e+06  658946.000000  653266.000000
#  3  0.511574  5.059562e-01       0.511115       0.498387
#  4  0.488426  4.940438e-01       0.488885       0.501613
#
#    Northern regions combined  \
#  0                       NaN
#  1                       NaN
#  2                   5825879
#  3                   0.50838
#  4                   0.49162
#
#                                                Source Page#  Date  \
#  0                                                NaN   NaN   NaN
#  1                                                NaN   NaN   NaN
#  2  https://www.statsghana.gov.gh/gssmain/fileUplo...  118+  2021
#  3  https://www.statsghana.gov.gh/gssmain/fileUplo...  118+  2021
#  4  https://www.statsghana.gov.gh/gssmain/fileUplo...  118+  2021
#
#    Alternative ways to phrase/perspective
#  0                                    NaN
#  1                                    NaN
#  2                                    NaN
#  3                                    NaN
#  4                                    NaN  )

# %% [markdown]
# Now we manipulate the dataframe so that the regions are the rows and the type of aggregate information is the column

# %%
# Keep only education related rows
df_subset = df_general_stats.iloc[143:186].copy()

# Set the first column as the new index (features)
df_transformed = df_subset.set_index('Use the + or - at the left of the row numbers to open/close the groups')

# Transpose the DataFrame so that the columns from Ghana to Northern regions combined become rows
df_transformed = df_transformed.loc[:, 'Ghana':'Northern regions combined'].T

cols_to_drop = ['Achievement','Access','Pre-Primary','Primary','Secondary']
aggregate_education = df_transformed.drop(columns=cols_to_drop)

# Display the transformed DataFrame
aggregate_education
# Out:
# Use the + or - at the left of the row numbers to open/close the groups Literacy rate among the male population between 6 - 15yrs  \
# Ghana                                                                                                                 NaN
# UER                                                                                                              0.464156
# Pre-2018 Northern Region                                                                                              NaN
# UWR                                                                                                               0.38774
# NR                                                                                                               0.360012
# NER                                                                                                              0.298172
# Sav.R                                                                                                             0.25905
# Northern regions combined                                                                                        0.353826
#
# Use the + or - at the left of the row numbers to open/close the groups Literacy rate among the female population aged 6-15yrs  \
# Ghana                                                                                                                 NaN
# UER                                                                                                              0.504267
# Pre-2018 Northern Region                                                                                              NaN
# UWR                                                                                                              0.418868
# NR                                                                                                               0.359498
# NER                                                                                                              0.306412
# Sav.R                                                                                                            0.273802
# Northern regions combined                                                                                        0.372569
#
# Use the + or - at the left of the row numbers to open/close the groups % of children living in households that have 3 or more childrens' books  \
# Ghana                                                                                                                 7.1
# UER                                                                                                                   2.9
# Pre-2018 Northern Region                                                                                              1.1
# UWR                                                                                                                   1.9
# NR                                                                                                                    NaN
# NER                                                                                                                   NaN
# Sav.R                                                                                                                 NaN
# Northern regions combined                                                                                        1.966667
#
# Use the + or - at the left of the row numbers to open/close the groups % of children who read books or are read to at home  \
# Ghana                                                                                                                64.2
# UER                                                                                                                  62.6
# Pre-2018 Northern Region                                                                                               47
# UWR                                                                                                                  50.9
# NR                                                                                                                    NaN
# NER                                                                                                                   NaN
# Sav.R                                                                                                                 NaN
# Northern regions combined                                                                                            53.5
#
# Use the + or - at the left of the row numbers to open/close the groups Median years of education for women (in years)  \
# Ghana                                                                                                             7.8
# UER                                                                                                               2.9
# Pre-2018 Northern Region                                                                                            0
# UWR                                                                                                                 1
# NR                                                                                                                NaN
# NER                                                                                                               NaN
# Sav.R                                                                                                             NaN
# Northern regions combined                                                                                    1.200602
#
# Use the + or - at the left of the row numbers to open/close the groups Median years of education for men (in years)  \
# Ghana                                                                                                           8.6
# UER                                                                                                               5
# Pre-2018 Northern Region                                                                                          3
# UWR                                                                                                             5.8
# NR                                                                                                              NaN
# NER                                                                                                             NaN
# Sav.R                                                                                                           NaN
# Northern regions combined                                                                                       NaN
#
# Use the + or - at the left of the row numbers to open/close the groups Median age of enrolment in school women (amongst women aged 15-24)  \
# Ghana                                                                                                                 6.5
# UER                                                                                                                   8.1
# Pre-2018 Northern Region                                                                                              7.6
# UWR                                                                                                                     8
# NR                                                                                                                    NaN
# NER                                                                                                                   NaN
# Sav.R                                                                                                                 NaN
# Northern regions combined                                                                                        7.853614
#
# Use the + or - at the left of the row numbers to open/close the groups Median age of enrolment in school men (amongst men aged 15-24)  \
# Ghana                                                                                                                 6.5
# UER                                                                                                                   6.9
# Pre-2018 Northern Region                                                                                              7.3
# UWR                                                                                                                   7.2
# NR                                                                                                                    NaN
# NER                                                                                                                   NaN
# Sav.R                                                                                                                 NaN
# Northern regions combined                                                                                        7.133333
#
# Use the + or - at the left of the row numbers to open/close the groups % of females over 6 with no education  \
# Ghana                                                                                                   19.1
# UER                                                                                                       40
# Pre-2018 Northern Region                                                                                65.8
# UWR                                                                                                     48.7
# NR                                                                                                       NaN
# NER                                                                                                      NaN
# Sav.R                                                                                                    NaN
# Northern regions combined                                                                               51.5
#
# Use the + or - at the left of the row numbers to open/close the groups % of females completed primary (and this remains their highest level of schooling)  \
# Ghana                                                                                                                 5.2
# UER                                                                                                                   7.4
# Pre-2018 Northern Region                                                                                              2.6
# UWR                                                                                                                   4.6
# NR                                                                                                                    NaN
# NER                                                                                                                   NaN
# Sav.R                                                                                                                 NaN
# Northern regions combined                                                                                        4.866667
#
# Use the + or - at the left of the row numbers to open/close the groups  ...  \
# Ghana                                                                   ...
# UER                                                                     ...
# Pre-2018 Northern Region                                                ...
# UWR                                                                     ...
# NR                                                                      ...
# NER                                                                     ...
# Sav.R                                                                   ...
# Northern regions combined                                               ...
#
# Use the + or - at the left of the row numbers to open/close the groups % of Primary school completion rate boys  \
# Ghana                                                                                                        99
# UER                                                                                                       107.5
# Pre-2018 Northern Region                                                                                   86.6
# UWR                                                                                                       111.6
# NR                                                                                                          NaN
# NER                                                                                                         NaN
# Sav.R                                                                                                       NaN
# Northern regions combined                                                                                 101.9
#
# Use the + or - at the left of the row numbers to open/close the groups Pupil to teacher ratio in primary   \
# Ghana                                                                                                 NaN
# UER                                                                                                    42
# Pre-2018 Northern Region                                                                               38
# UWR                                                                                                    37
# NR                                                                                                    NaN
# NER                                                                                                   NaN
# Sav.R                                                                                                 NaN
# Northern regions combined                                                                              39
#
# Use the + or - at the left of the row numbers to open/close the groups % of children over-age by 2 or more years  \
# Ghana                                                                                                         16
# UER                                                                                                         22.9
# Pre-2018 Northern Region                                                                                    20.1
# UWR                                                                                                         23.5
# NR                                                                                                           NaN
# NER                                                                                                          NaN
# Sav.R                                                                                                        NaN
# Northern regions combined                                                                              22.166667
#
# Use the + or - at the left of the row numbers to open/close the groups School age population  \
# Ghana                                                                                3706186
# UER                                                                                      NaN
# Pre-2018 Northern Region                                                                 NaN
# UWR                                                                                      NaN
# NR                                                                                       NaN
# NER                                                                                      NaN
# Sav.R                                                                                    NaN
# Northern regions combined                                                                NaN
#
# Use the + or - at the left of the row numbers to open/close the groups JHS completion rate girls  \
# Ghana                                                                                         66
# UER                                                                                          NaN
# Pre-2018 Northern Region                                                                     NaN
# UWR                                                                                          NaN
# NR                                                                                           NaN
# NER                                                                                          NaN
# Sav.R                                                                                        NaN
# Northern regions combined                                                                    NaN
#
# Use the + or - at the left of the row numbers to open/close the groups JHS completion rate boys  \
# Ghana                                                                                        72
# UER                                                                                         NaN
# Pre-2018 Northern Region                                                                    NaN
# UWR                                                                                         NaN
# NR                                                                                          NaN
# NER                                                                                         NaN
# Sav.R                                                                                       NaN
# Northern regions combined                                                                   NaN
#
# Use the + or - at the left of the row numbers to open/close the groups Pupil to teacher ratio in JHS  \
# Ghana                                                                                            NaN
# UER                                                                                               19
# Pre-2018 Northern Region                                                                          21
# UWR                                                                                               16
# NR                                                                                               NaN
# NER                                                                                              NaN
# Sav.R                                                                                            NaN
# Northern regions combined                                                                  18.666667
#
# Use the + or - at the left of the row numbers to open/close the groups % of children over-age by 2 or more years\n(Lower Secondary School)  \
# Ghana                                                                                                                34.5
# UER                                                                                                                  47.2
# Pre-2018 Northern Region                                                                                             45.6
# UWR                                                                                                                  53.1
# NR                                                                                                                    NaN
# NER                                                                                                                   NaN
# Sav.R                                                                                                                 NaN
# Northern regions combined                                                                                       48.633333
#
# Use the + or - at the left of the row numbers to open/close the groups Disabilities  \
# Ghana                                                                           NaN
# UER                                                                             NaN
# Pre-2018 Northern Region                                                        NaN
# UWR                                                                             NaN
# NR                                                                              NaN
# NER                                                                             NaN
# Sav.R                                                                           NaN
# Northern regions combined                                                       NaN
#
# Use the + or - at the left of the row numbers to open/close the groups Pecentage of the female population, above 5 years, who have varying degrees of difficulty in performing activities
# Ghana                                                                                                               0.088
# UER                                                                                                              0.101746
# Pre-2018 Northern Region                                                                                              NaN
# UWR                                                                                                              0.107106
# NR                                                                                                                0.07156
# NER                                                                                                              0.072926
# Sav.R                                                                                                            0.072255
# Northern regions combined                                                                                             NaN
#
# [8 rows x 38 columns]

# %%
aggregate_education.iloc[:,[0,1]]
# Out:
# Use the + or - at the left of the row numbers to open/close the groups Literacy rate among the male population between 6 - 15yrs  \
# Ghana                                                                                                                 NaN
# UER                                                                                                              0.464156
# Pre-2018 Northern Region                                                                                              NaN
# UWR                                                                                                               0.38774
# NR                                                                                                               0.360012
# NER                                                                                                              0.298172
# Sav.R                                                                                                             0.25905
# Northern regions combined                                                                                        0.353826
#
# Use the + or - at the left of the row numbers to open/close the groups Literacy rate among the female population aged 6-15yrs
# Ghana                                                                                                                 NaN
# UER                                                                                                              0.504267
# Pre-2018 Northern Region                                                                                              NaN
# UWR                                                                                                              0.418868
# NR                                                                                                               0.359498
# NER                                                                                                              0.306412
# Sav.R                                                                                                            0.273802
# Northern regions combined                                                                                        0.372569

# %% [markdown]
# ### Correlations

# %%
cols = ['Literacy rate among the male population between 6 - 15yrs',
 'Literacy rate among the female population aged 6-15yrs','% of women aged 15-24 who stopped school to get married',
 '% of women aged 15-24 who stopped school due to unaffordable fees',
 '% of males aged 15-24 who stopped school due to unnaffordable fees',
 'School age population', '% of Primary school completion rate girls',
 '% of Primary school completion rate boys',
 'Pupil to teacher ratio in primary ']

# %%
aggregate_education[cols].corr()
# Out:
# Use the + or - at the left of the row numbers to open/close the groups  Literacy rate among the male population between 6 - 15yrs  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                               1.000000
# Literacy rate among the female population aged ...                                                               0.991207
# % of women aged 15-24 who stopped school to get...                                                              -0.293198
# % of women aged 15-24 who stopped school due to...                                                              -0.672055
# % of males aged 15-24 who stopped school due to...                                                               1.000000
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# % of Primary school completion rate girls                                                                        0.999186
# % of Primary school completion rate boys                                                                         0.383697
# Pupil to teacher ratio in primary                                                                                0.756148
#
# Use the + or - at the left of the row numbers to open/close the groups  Literacy rate among the female population aged 6-15yrs  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                               0.991207
# Literacy rate among the female population aged ...                                                               1.000000
# % of women aged 15-24 who stopped school to get...                                                              -0.245938
# % of women aged 15-24 who stopped school due to...                                                              -0.634915
# % of males aged 15-24 who stopped school due to...                                                               1.000000
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# % of Primary school completion rate girls                                                                        0.999962
# % of Primary school completion rate boys                                                                         0.428542
# Pupil to teacher ratio in primary                                                                                0.723131
#
# Use the + or - at the left of the row numbers to open/close the groups  % of women aged 15-24 who stopped school to get married  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                              -0.293198
# Literacy rate among the female population aged ...                                                              -0.245938
# % of women aged 15-24 who stopped school to get...                                                               1.000000
# % of women aged 15-24 who stopped school due to...                                                               0.439995
# % of males aged 15-24 who stopped school due to...                                                              -0.627392
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# % of Primary school completion rate girls                                                                        0.198100
# % of Primary school completion rate boys                                                                         0.664110
# Pupil to teacher ratio in primary                                                                               -0.488792
#
# Use the + or - at the left of the row numbers to open/close the groups  % of women aged 15-24 who stopped school due to unaffordable fees  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                              -0.672055
# Literacy rate among the female population aged ...                                                              -0.634915
# % of women aged 15-24 who stopped school to get...                                                               0.439995
# % of women aged 15-24 who stopped school due to...                                                               1.000000
# % of males aged 15-24 who stopped school due to...                                                              -0.369340
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# % of Primary school completion rate girls                                                                       -0.400604
# % of Primary school completion rate boys                                                                        -0.019670
# Pupil to teacher ratio in primary                                                                               -0.983620
#
# Use the + or - at the left of the row numbers to open/close the groups  % of males aged 15-24 who stopped school due to unnaffordable fees  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                               1.000000
# Literacy rate among the female population aged ...                                                               1.000000
# % of women aged 15-24 who stopped school to get...                                                              -0.627392
# % of women aged 15-24 who stopped school due to...                                                              -0.369340
# % of males aged 15-24 who stopped school due to...                                                               1.000000
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# School age population                                                                                                 NaN
# % of Primary school completion rate girls                                                                        0.553028
# % of Primary school completion rate boys                                                                         0.129236
# Pupil to teacher ratio in primary                                                                                0.937509
#
# Use the + or - at the left of the row numbers to open/close the groups  School age population  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                        NaN
# Literacy rate among the female population aged ...                                        NaN
# % of women aged 15-24 who stopped school to get...                                        NaN
# % of women aged 15-24 who stopped school due to...                                        NaN
# % of males aged 15-24 who stopped school due to...                                        NaN
# School age population                                                                     NaN
# School age population                                                                     NaN
# School age population                                                                     NaN
# % of Primary school completion rate girls                                                 NaN
# % of Primary school completion rate boys                                                  NaN
# Pupil to teacher ratio in primary                                                         NaN
#
# Use the + or - at the left of the row numbers to open/close the groups  School age population  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                        NaN
# Literacy rate among the female population aged ...                                        NaN
# % of women aged 15-24 who stopped school to get...                                        NaN
# % of women aged 15-24 who stopped school due to...                                        NaN
# % of males aged 15-24 who stopped school due to...                                        NaN
# School age population                                                                     NaN
# School age population                                                                     NaN
# School age population                                                                     NaN
# % of Primary school completion rate girls                                                 NaN
# % of Primary school completion rate boys                                                  NaN
# Pupil to teacher ratio in primary                                                         NaN
#
# Use the + or - at the left of the row numbers to open/close the groups  School age population  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                        NaN
# Literacy rate among the female population aged ...                                        NaN
# % of women aged 15-24 who stopped school to get...                                        NaN
# % of women aged 15-24 who stopped school due to...                                        NaN
# % of males aged 15-24 who stopped school due to...                                        NaN
# School age population                                                                     NaN
# School age population                                                                     NaN
# School age population                                                                     NaN
# % of Primary school completion rate girls                                                 NaN
# % of Primary school completion rate boys                                                  NaN
# Pupil to teacher ratio in primary                                                         NaN
#
# Use the + or - at the left of the row numbers to open/close the groups  % of Primary school completion rate girls  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                       0.999186
# Literacy rate among the female population aged ...                                                       0.999962
# % of women aged 15-24 who stopped school to get...                                                       0.198100
# % of women aged 15-24 who stopped school due to...                                                      -0.400604
# % of males aged 15-24 who stopped school due to...                                                       0.553028
# School age population                                                                                         NaN
# School age population                                                                                         NaN
# School age population                                                                                         NaN
# % of Primary school completion rate girls                                                                1.000000
# % of Primary school completion rate boys                                                                 0.858327
# Pupil to teacher ratio in primary                                                                        0.571473
#
# Use the + or - at the left of the row numbers to open/close the groups  % of Primary school completion rate boys  \
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                      0.383697
# Literacy rate among the female population aged ...                                                      0.428542
# % of women aged 15-24 who stopped school to get...                                                      0.664110
# % of women aged 15-24 who stopped school due to...                                                     -0.019670
# % of males aged 15-24 who stopped school due to...                                                      0.129236
# School age population                                                                                        NaN
# School age population                                                                                        NaN
# School age population                                                                                        NaN
# % of Primary school completion rate girls                                                               0.858327
# % of Primary school completion rate boys                                                                1.000000
# Pupil to teacher ratio in primary                                                                       0.179005
#
# Use the + or - at the left of the row numbers to open/close the groups  Pupil to teacher ratio in primary
# Use the + or - at the left of the row numbers t...
# Literacy rate among the male population between...                                                0.756148
# Literacy rate among the female population aged ...                                                0.723131
# % of women aged 15-24 who stopped school to get...                                               -0.488792
# % of women aged 15-24 who stopped school due to...                                               -0.983620
# % of males aged 15-24 who stopped school due to...                                                0.937509
# School age population                                                                                  NaN
# School age population                                                                                  NaN
# School age population                                                                                  NaN
# % of Primary school completion rate girls                                                         0.571473
# % of Primary school completion rate boys                                                          0.179005
# Pupil to teacher ratio in primary                                                                 1.000000
